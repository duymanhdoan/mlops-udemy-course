# %%
from flask import Flask, request
import pickle
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# sample_data  text_classifier_pytorch  tfidfmodel.pickle

# %%
input_size=467
output_size=2
hidden_size=500

# %%
class Net(nn.Module):
   def __init__(self):
       super(Net, self).__init__()
       self.fc1 = torch.nn.Linear(input_size, hidden_size)
       self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
       self.fc3 = torch.nn.Linear(hidden_size, output_size)


   def forward(self, X):
       X = torch.relu((self.fc1(X)))
       X = torch.relu((self.fc2(X)))
       X = self.fc3(X)

       return F.log_softmax(X,dim=1)

# %%
model = Net()

# %%
# !ls
# Out:
# sample_data  text_classifier_pytorch  tfidfmodel.pickle

# %%
model.load_state_dict(torch.load('text_classifier_pytorch'))
# Out:
# <All keys matched successfully>

# %%
# !pip install flask-ngrok
# Out:
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.6/dist-packages (0.0.25)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.6/dist-packages (from flask-ngrok) (1.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->flask-ngrok) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok) (1.1.1)

# %%
from flask_ngrok import run_with_ngrok

# %%
app = Flask(__name__)

# %%
run_with_ngrok(app)

# %%
# !ls
# Out:
# sample_data  text_classifier_pytorch  tfidfmodel.pickle

# %%
with open('tfidfmodel.pickle','rb') as file:
    tfidf = pickle.load(file)

# %%
@app.route('/predict',methods=['POST'])
def customer_behavior():
    request_data = request.get_json(force=True)
    text = request_data['sentence']
    print("printing the sentence")
    print(text)
    text_list=[]
    text_list.append(text)
    print(text_list)
    numeric_text = tfidf.transform(text_list).toarray()
    output = model(torch.from_numpy(numeric_text).float())
    print("Printing predictions")
    print(output[:,0][0])
    print(output[:,1][0])
    sentiment="unknown"
    if torch.gt(output[:,0][0],output[:,1][0]):
      print("negative prediction")
      sentiment="negative"
    else:
      print("positive prediction")
      sentiment="positive"
    print("Printing prediction")     
    print(sentiment)
    return sentiment

# %%
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://50bbef5502be.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# [2020-12-24 00:59:23,702] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:23] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:23,801] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:23] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:23,900] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:23] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# ['rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc']
# [['rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc']]
# printing the sentence
# ['desantis signs executive order giving seniors vaccine priority over essential workers https t co c enwpumw ']
# [['desantis signs executive order giving seniors vaccine priority over essential workers https t co c enwpumw ']]
# printing the sentence
# ['i deserve the vaccine first because i want to go viral on tik tok safely']
# [['i deserve the vaccine first because i want to go viral on tik tok safely']]
# [2020-12-24 00:59:23,996] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:23] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:24,094] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:24,191] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# ['rt hard jewelry is the vaccine sativa or indica genuinely curious before i take it']
# [['rt hard jewelry is the vaccine sativa or indica genuinely curious before i take it']]
# printing the sentence
# ['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']
# [['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']]
# printing the sentence
# [' mike pence they injected socialism right into your arm when you got the vaccine yoy hypocrite our how about that https t co ytkaf rlry']
# [[' mike pence they injected socialism right into your arm when you got the vaccine yoy hypocrite our how about that https t co ytkaf rlry']]
# [2020-12-24 00:59:24,291] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:24,387] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:24,489] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# [' the latest delay is a blow to beijing which has been racing to catch up with western drugmakers and will add to https t co  chzuwpjux']
# [[' the latest delay is a blow to beijing which has been racing to catch up with western drugmakers and will add to https t co  chzuwpjux']]
# printing the sentence
# ['rt trinityresists when the rich amp privileged who downplayed covid mocked wearing masks called it a hoax attended superspreader events ']
# [['rt trinityresists when the rich amp privileged who downplayed covid mocked wearing masks called it a hoax attended superspreader events ']]
# printing the sentence
# ['rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co uku ftkjib https t co  fqfonmak ']
# [['rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co uku ftkjib https t co  fqfonmak ']]
# [2020-12-24 00:59:24,592] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:24,690] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:24,785] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# ['rt willmenaker the pfizer vaccine is sativa the moderna one is indica']
# [['rt willmenaker the pfizer vaccine is sativa the moderna one is indica']]
# printing the sentence
# ['rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc']
# [['rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc']]
# printing the sentence
# [' briantylercohen realdonaldtrump with all due respect it is impossible to lay all the deaths at trump s feet it https t co  jsw zthct']
# [[' briantylercohen realdonaldtrump with all due respect it is impossible to lay all the deaths at trump s feet it https t co  jsw zthct']]
# [2020-12-24 00:59:24,884] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:24,982] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:24] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:25,079] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# ['rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co uku ftkjib https t co  fqfonmak ']
# [['rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co uku ftkjib https t co  fqfonmak ']]
# printing the sentence
# ['if you were on tumblr between      and      the vaccine should worry about what s in you']
# [['if you were on tumblr between      and      the vaccine should worry about what s in you']]
# printing the sentence
# ['one of my employees asked me when we would be offered the vaccine we work from home we talk to patients over the https t co cj xaxnbee']
# [['one of my employees asked me when we would be offered the vaccine we work from home we talk to patients over the https t co cj xaxnbee']]
# [2020-12-24 00:59:25,182] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:25,280] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:25,378] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# ['rt nbsaphiermd going in now for a full day of seeing patients while i nor them haven t been offered the vaccine yet because we are pri ']
# [['rt nbsaphiermd going in now for a full day of seeing patients while i nor them haven t been offered the vaccine yet because we are pri ']]
# printing the sentence
# ['rt nbsaphiermd going in now for a full day of seeing patients while i nor them haven t been offered the vaccine yet because we are pri ']
# [['rt nbsaphiermd going in now for a full day of seeing patients while i nor them haven t been offered the vaccine yet because we are pri ']]
# printing the sentence
# ['rt benjaminjpauli within five days of receiving their first pfizer covid    vaccines mclaren flint hospital and hurley medical center h ']
# [['rt benjaminjpauli within five days of receiving their first pfizer covid    vaccines mclaren flint hospital and hurley medical center h ']]
# [2020-12-24 00:59:25,476] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:25,570] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:25,664] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# ['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']
# [['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']]
# printing the sentence
# ['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']
# [['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']]
# printing the sentence
# ['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']
# [['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']]
# [2020-12-24 00:59:25,757] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:25] "POST /predict HTTP/1.1" 500 -
# [2020-12-24 00:59:25,854] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
# ...
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-15-b84f9dcbe6c0>", line 10, in customer_behavior
#     numeric_text = tfidf.transform(text_list).toarray()
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1898, in transform
#     X = super().transform(raw_documents)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1270, in transform
#     _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 1131, in _count_vocab
#     for feature in analyze(doc):
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 103, in _analyze
#     doc = preprocessor(doc)
#   File "/usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py", line 68, in _preprocess
#     doc = doc.lower()
# AttributeError: 'list' object has no attribute 'lower'
# 127.0.0.1 - - [24/Dec/2020 00:59:42] "POST /predict HTTP/1.1" 500 -
# printing the sentence
# ['rt fiatlux usa nobody has to die nor do we need to subject ourselves to the risks of a dangerous vaccine hydroxychloroquine hcq is ']
# [['rt fiatlux usa nobody has to die nor do we need to subject ourselves to the risks of a dangerous vaccine hydroxychloroquine hcq is ']]
# printing the sentence
# ['rt maxonthecoast imagine what this would look like had the whole vaccine issue been handled competently from the beginning instead we b ']
# [['rt maxonthecoast imagine what this would look like had the whole vaccine issue been handled competently from the beginning instead we b ']]
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# printing the sentence
# rt davidsa         rec       essexcanning matthancock borisjohnson bbcnews he s wasted billions on ppe contracts for party donors t
# ['rt davidsa         rec       essexcanning matthancock borisjohnson bbcnews he s wasted billions on ppe contracts for party donors t ']
# Printing predictions
# tensor(-0.4395, grad_fn=<SelectBackward>)
# tensor(-1.0339, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# my mom found out that she will be getting the vaccine right after the holidays i cannot wait to hug her again
# ['my mom found out that she will be getting the vaccine right after the holidays i cannot wait to hug her again ']
# Printing predictions
# tensor(-1.9438, grad_fn=<SelectBackward>)
# tensor(-0.1545, grad_fn=<SelectBackward>)
# positive prediction
# Printing prediction
# positive
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# printing the sentence
# rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co p ioagd m  https t co zywus bkp
# ['rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co p ioagd m  https t co zywus bkp ']
# Printing predictions
# tensor(-0.4395, grad_fn=<SelectBackward>)
# tensor(-1.0339, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
#  but they still don t have a vaccine for cancer loooookin asssss https t co vkpqbvhtc
# [' but they still don t have a vaccine for cancer loooookin asssss https t co vkpqbvhtc ']
# Printing predictions
# tensor(0., grad_fn=<SelectBackward>)
# tensor(-23.0707, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc
# ['rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc']
# Printing predictions
# tensor(0., grad_fn=<SelectBackward>)
# tensor(-17.2332, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# printing the sentence
#  news     media wants to make this a racisms issued these academics have nothing better to do than to keep feeding https t co mwg  twuhp
# [' news     media wants to make this a racisms issued these academics have nothing better to do than to keep feeding https t co mwg  twuhp']
# Printing predictions
# tensor(-8.6726, grad_fn=<SelectBackward>)
# tensor(-0.0002, grad_fn=<SelectBackward>)
# positive prediction
# Printing prediction
# positive
# printing the sentence
# it s funny cause i ve seen so many of yall do every type of drug but the vaccine is where you cross the line
# ['it s funny cause i ve seen so many of yall do every type of drug but the vaccine is where you cross the line ']
# Printing predictions
# tensor(-0.4395, grad_fn=<SelectBackward>)
# tensor(-1.0339, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co uku ftkjib https t co  fqfonmak
# ['rt reuters moderna expects its covid    vaccine to protect against uk coronavirus variant https t co uku ftkjib https t co  fqfonmak ']
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# Printing predictions
# tensor(-0.4395, grad_fn=<SelectBackward>)
# tensor(-1.0339, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z
# ['rt thekillakay  not trusting the vaccine unless these   make it https t co  z wkcho z']
# Printing predictions
# tensor(-1.1921e-07, grad_fn=<SelectBackward>)
# tensor(-15.7632, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
#  kevinkrooss joshtpm he got it got tested went swimming in the senate pool then got the results and now tells https t co m tyhy jts
# [' kevinkrooss joshtpm he got it got tested went swimming in the senate pool then got the results and now tells https t co m tyhy jts']
# Printing predictions
# tensor(0., grad_fn=<SelectBackward>)
# 127.0.0.1 - - [24/Dec/2020 01:01:06] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# tensor(-23.0496, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
#  kindaglitched im just seeing all those memes about people saying they ll throw parties once they get the vaccine b https t co w dbbtxk
# [' kindaglitched im just seeing all those memes about people saying they ll throw parties once they get the vaccine b https t co w dbbtxk  ']
# Printing predictions
# tensor(0., grad_fn=<SelectBackward>)
# tensor(-17.2332, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
#  agentx     dc draino educate yourself no vaccine has ever proven effective ever not one single one has been te https t co  ofmaxspl
# [' agentx     dc draino educate yourself no vaccine has ever proven effective ever not one single one has been te https t co  ofmaxspl ']
# Printing predictions
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# tensor(-1.1921e-07, grad_fn=<SelectBackward>)
# tensor(-16.2543, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt vicxhowarth wear a face mask and get the fucking vaccine i want to see my chemical romance next year
# ['rt vicxhowarth wear a face mask and get the fucking vaccine i want to see my chemical romance next year']
# Printing predictions
# tensor(-2.7418e-06, grad_fn=<SelectBackward>)
# tensor(-12.8179, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# this is the kind of ignorant comment frequently being seen this dr should realize   dr henry agreed to get a va https t co dfez ntxdt
# ['this is the kind of ignorant comment frequently being seen this dr should realize   dr henry agreed to get a va https t co dfez ntxdt']
# Printing predictions
# tensor(-0.0001, grad_fn=<SelectBackward>)
# tensor(-8.8242, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# printing the sentence
# rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc
# ['rt acn berry me amp the girls after we get the vaccine https t co gk  kk szc']
# Printing predictions
# tensor(0., grad_fn=<SelectBackward>)
# tensor(-17.2332, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt drvyom so far           doses of the pfizer vaccine have been administered in usa and so far less than    reported severe allergic r
# ['rt drvyom so far           doses of the pfizer vaccine have been administered in usa and so far less than    reported severe allergic r ']
# Printing predictions
# tensor(-14.6770, grad_fn=<SelectBackward>)
# tensor(-4.7684e-07, grad_fn=<SelectBackward>)
# positive prediction
# Printing prediction
# positive
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# printing the sentence
# rt humanheadline pardon my puzzlement genuine question if covid vaccinations are happening now in the us and the uk why won t australia
# ['rt humanheadline pardon my puzzlement genuine question if covid vaccinations are happening now in the us and the uk why won t australia ']
# Printing predictions
# tensor(-14.5113, grad_fn=<SelectBackward>)
# tensor(-4.7684e-07, grad_fn=<SelectBackward>)
# positive prediction
# Printing prediction
# positive
# printing the sentence
#  rec       essexcanning matthancock borisjohnson bbcnews he s wasted billions on ppe contracts for party donors https t co qyuszwugcn
# [' rec       essexcanning matthancock borisjohnson bbcnews he s wasted billions on ppe contracts for party donors https t co qyuszwugcn']
# Printing predictions
# tensor(-0.4395, grad_fn=<SelectBackward>)
# tensor(-1.0339, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
#  instablog ja ehhh don t worry we don t need the vaccine again just give us agbo
# [' instablog ja ehhh don t worry we don t need the vaccine again just give us agbo']
# Printing predictions
# tensor(-0.0134, grad_fn=<SelectBackward>)
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:07] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# tensor(-4.3205, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
#  ocgn ocugen is just getting started their covid    vaccine from india is already in phase   stage lets go https t co vnpprbttxi
# [' ocgn ocugen is just getting started their covid    vaccine from india is already in phase   stage lets go https t co vnpprbttxi']
# Printing predictions
# tensor(-1.5259e-05, grad_fn=<SelectBackward>)
# tensor(-11.0901, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt bowenchris the tga should take the time it needs to approve vaccines amp ensure public confidence once the tga has approved the pfize
# ['rt bowenchris the tga should take the time it needs to approve vaccines amp ensure public confidence once the tga has approved the pfize ']
# Printing predictions
# tensor(-18.5443, grad_fn=<SelectBackward>)
# tensor(0., grad_fn=<SelectBackward>)
# positive prediction
# Printing prediction
# positive
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# printing the sentence
# rt rowdysabian if you re a fan of the undertaker don t worry about what s in the vaccine
# ['rt rowdysabian if you re a fan of the undertaker don t worry about what s in the vaccine']
# Printing predictions
# tensor(-0.4395, grad_fn=<SelectBackward>)
# tensor(-1.0339, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt willmenaker the pfizer vaccine is sativa the moderna one is indica
# ['rt willmenaker the pfizer vaccine is sativa the moderna one is indica']
# Printing predictions
# tensor(-6.4373e-06, grad_fn=<SelectBackward>)
# tensor(-11.9572, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt landau       tiffanydoverdead after covid    vaccine https t co bh hsrha i
# ['rt landau       tiffanydoverdead after covid    vaccine https t co bh hsrha i']
# Printing predictions
# tensor(-0.4395, grad_fn=<SelectBackward>)
# tensor(-1.0339, grad_fn=<SelectBackward>)
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# negative prediction
# Printing prediction
# negative
# printing the sentence
# nurse friends i need that day by day report about the vaccine please
# ['nurse friends i need that day by day report about the vaccine please']
# Printing predictions
# tensor(-23.7618, grad_fn=<SelectBackward>)
# tensor(0., grad_fn=<SelectBackward>)
# positive prediction
# Printing prediction
# positive
# printing the sentence
# rt vicxhowarth wear a face mask and get the fucking vaccine i want to see my chemical romance next year
# ['rt vicxhowarth wear a face mask and get the fucking vaccine i want to see my chemical romance next year']
# Printing predictions
# tensor(-2.7418e-06, grad_fn=<SelectBackward>)
# tensor(-12.8179, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# printing the sentence
# rt chuuew what do you mean the vaccine is
# ['rt chuuew what do you mean the vaccine is     ']
# Printing predictions
# tensor(0., grad_fn=<SelectBackward>)
# tensor(-28.0247, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt gray mackenzie breaking health canada has approved the moderna vaccine for use in canada we are expected to received   million dose
# ['rt gray mackenzie breaking health canada has approved the moderna vaccine for use in canada we are expected to received   million dose ']
# Printing predictions
# tensor(0., grad_fn=<SelectBackward>)
# tensor(-19.5743, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
# rt nihdirector proud moment last night as us fda announced eua for moderna tx covid   vaccine mrna      co developed by nih a prim
# ['rt nihdirector proud moment last night as us fda announced eua for moderna tx covid   vaccine mrna      co developed by nih a prim ']
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Dec/2020 01:01:08] "POST /predict HTTP/1.1" 200 -
# Printing predictions
# tensor(-0.0003, grad_fn=<SelectBackward>)
# tensor(-8.2696, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
# printing the sentence
#  jayrobi         me too the woman did say something about the oxford vaccine at very beginning i think i didn t https t co kbqajatiwo
# [' jayrobi         me too the woman did say something about the oxford vaccine at very beginning i think i didn t https t co kbqajatiwo']
# Printing predictions
# tensor(-0.1062, grad_fn=<SelectBackward>)
# tensor(-2.2947, grad_fn=<SelectBackward>)
# negative prediction
# Printing prediction
# negative
